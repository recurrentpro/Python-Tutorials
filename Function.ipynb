# %%
a = 5
b = 4
c = a+b
print(c)

# %%
a = 15
b = 23
c = a+b
print(c)

# %%
x = 2
y = x**2+2*x
print(y)

# %%
z = y + 28
print(z)

# %%
#Defining the function
def equation(x):
    y = x**2+2*x
    print(y)
    
equation(25) #Calling the function [2-> 6-> 2-> 3-> 4]

# %% [markdown]
# # Return Statement

# %%
import math
r = math.sqrt(25)
print("Square Root of 25 is ", r)

# %%
def square_root(x):
    ans = x**(1/2)
    print(ans)
    
r = square_root(25)
print("Sqare Root of 25 is ", r)

# %%
def square_root(x):
    ans = x**(1/2)
    return(ans)
    
r = square_root(25)
print("Sqare Root of 25 is ", r)

# %% [markdown]
# # Method & Function:
#
# Method: When we define a function inside the class, we are calling method.

# %% [markdown]
# # 3. Anonymous Function
#
# we are defining anonymous fucntion with lambda keyword

# %%
result = lambda x, y, z: 2*x+y+z

# %%
result(5, 7, 3)

# %%
#Example

# %%
a = [4, 6,2, 12, 13, 21, 34, 26]

# %%
def even(x):
    if x%2==0:
        return x

list(filter(even, a))

# %%
list(filter(lambda x: x%2==0, a))

# %% [markdown]
# # 4. Recursion fucntion
#
# A function call itself, calling recursion function

# %%
def process():
    print("Hello world")
    process()
    
process()
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# ...

# %%
import sys

# %%
sys.setrecursionlimit(8000)

# %%
sys.getrecursionlimit()
# Out:
# 8000

# %%
def process(n):
    if n == 0:
        return "Recursion done!"
    print("Hello world",n)
    return process(n-1)
    
process(5)
# Out:
# Hello world 5
# Hello world 4
# Hello world 3
# Hello world 2
# Hello world 1
# 'Recursion done!'

# %%
def hello():
    a = 4
    b = 8
    return(a+b)
    print("Hello world")
    ajsdgkljldajklsdfkljkshdkg
    
hello()
# Out:
# 12

# %% [markdown]
# # Factorial Number with recursion function

# %%
def fact(n):
    if n==1:
        return 1
    return n*fact(n-1)

inpt = int(input("Enter the number for factorial: "))
fact(inpt)
# Out:
# Enter the number for factorial: 8
# 40320
